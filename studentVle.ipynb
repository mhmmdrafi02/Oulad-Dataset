# %% [markdown]
# # **EDA (Exploratory Data Analysis)**

# %%
# Melakukan import beberapa libary yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset studentVle.csv dari Google Drive
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/Dataset_Sem7/dataset_oulad/studentVle.csv"

# Membaca dataset dari file CSV
df = pd.read_csv(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Melihat informasi dasar tentang dataset
print("Informasi Dataset:")
df.info()
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 487.8+ MB

# %%
# Menampilkan 5 baris pertama dari dataset
print("\n5 Baris Pertama Dataset:")
df.head()
# Out:
# 5 Baris Pertama Dataset:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
# Tampilkan 5 data terbawah
print("\n5 Data Terbawah:")
df.tail()
# Out:
# 5 Data Terbawah:
#          code_module code_presentation  id_student  id_site  date  sum_click
# 10655275         GGG             2014J      675811   896943   269          3
# 10655276         GGG             2014J      675578   896943   269          1
# 10655277         GGG             2014J      654064   896943   269          3
# 10655278         GGG             2014J      654064   896939   269          1
# 10655279         GGG             2014J      654064   896939   269          1

# %%
# Statistik deskriptif untuk kolom numerik
print("\nStatistik Deskriptif:")
df.describe().astype(int)
# Out:
# Statistik Deskriptif:
#        id_student   id_site      date  sum_click
# count    10655280  10655280  10655280   10655280
# mean       733333    738323        95          3
# std        582705    131219        76          8
# min          6516    526721       -25          1
# 25%        507743    673519        25          1
# 50%        588236    730069        86          2
# 75%        646484    877030       156          3
# max       2698588   1049562       269       6977

# %% [markdown]
# #**Preprocessing**

# %%
# Visualisasi ini akan menunjukkan total sum_click untuk setiap kombinasi code_module dan code_presentation.
# Mengelompokkan data berdasarkan 'code_module' dan 'code_presentation' serta menghitung jumlah 'sum_click'
grouped_data = df.groupby(['code_module', 'code_presentation'])['sum_click'].sum().reset_index()

# Membuat plot batang untuk data yang dihasilkan
plt.figure(figsize=(12, 6))
plt.bar(range(len(grouped_data)), grouped_data['sum_click'])
plt.xlabel('Kombinasi code_module dan code_presentation')
plt.ylabel('Total sum_click')
plt.title('Total sum_click per Kombinasi code_module dan code_presentation')
plt.xticks(range(len(grouped_data)), grouped_data['code_module'] + ' ' + grouped_data['code_presentation'], rotation=45)
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
# Diagram Sebar (Scatter Plot)
# Visualisasi ini akan menunjukkan hubungan antara date dan sum_click
plt.figure(figsize=(12, 6))
plt.scatter(df['date'], df['sum_click'], alpha=0.5)
plt.xlabel('Date')
plt.ylabel('sum_click')
plt.title('Hubungan antara Date dan sum_click')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Menampilkan jumlah missing values pada setiap kolom
missing_data = df.isnull().sum()
print(df.isnull().sum())
# Out:
# code_module          0
# code_presentation    0
# id_student           0
# id_site              0
# date                 0
# sum_click            0
# dtype: int64

# %%
# Menampilkan jumlah total missing values dalam dataset
total_missing_values = missing_data.sum()
print("Total Missing Values dalam Dataset:",total_missing_values)
# Out:
# Total Missing Values dalam Dataset: 0
